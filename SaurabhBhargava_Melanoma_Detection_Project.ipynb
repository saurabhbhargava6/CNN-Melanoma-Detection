# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabhbhargava6/CNN-Melanoma-Detection/blob/main/SaurabhBhargava_Melanoma_Detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem statement:
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
#import the required libraries
import pathlib
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

from tensorflow.keras.preprocessing.image import load_img

from glob import glob

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive

# import shutil
# folder_path = 'Skin cancer ISIC The International Skin Imaging Collaboration'

# # Use shutil.rmtree to delete the folder and its contents
# shutil.rmtree(folder_path)

drive.flush_and_unmount()

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# In case of google drive
# !unzip -o -q "/content/gdrive/MyDrive/ColabNotebooks/CNN_assignment.zip"

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
#list directory in train folder
dir_train = os.listdir(data_dir_train)
dir_train.sort()
dir_train
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
#both test & train have same folders (disease folder ), now check the no. of datapoints in each folder

#total train dataset
total_train_data = len(list(data_dir_train.glob("*/*.jpg")))
total_train_data
# Out:
# 2239

# %%
#total test dataset
total_test_data = len(list(data_dir_test.glob("*/*.jpg")))
total_test_data
# Out:
# 118

# %%
def class_distribution_count(directory):
    train_path_list = list(directory.glob('*/*.jpg'))
    df=pd.DataFrame({"cancer_type":[str(x).split("/")[2] for x in train_path_list]})
    df['cancer_type'].value_counts().plot(kind='bar')
    plt.title("Distribution of classes")
    plt.show()

    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                                if os.path.isfile(os.path.join(path, name))]))

    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]

    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'Count of Image'])

# %% [markdown]
# <div class="jp-Cell jp-MarkdownCell jp-Notebook-cell">
# <div class="jp-Cell-inputWrapper">
# <div class="jp-InputArea jp-Cell-inputArea">
# <div class="jp-RenderedHTMLCommon jp-RenderedMarkdown jp-MarkdownOutput" data-mime-type="text/markdown">
# <h3 id="Load-using-keras.preprocessing">Load using keras.preprocessing</h3>
# <p>Let's load these images off disk using the helpful image_dataset_from_directory utility.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="jp-Cell jp-MarkdownCell jp-Notebook-cell">
# <div class="jp-Cell-inputWrapper">
# <div class="jp-Collapser jp-InputCollapser jp-Cell-inputCollapser">&nbsp;</div>
# <div class="jp-InputArea jp-Cell-inputArea">
# <div class="jp-InputPrompt jp-InputArea-prompt">&nbsp;</div>
# <div class="jp-RenderedHTMLCommon jp-RenderedMarkdown jp-MarkdownOutput" data-mime-type="text/markdown">
# <h3 id="Create-a-dataset">Create a dataset</h3>
# <p>Define some parameters for the loader:</p>
# </div>
# </div>
# </div>
# </div>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
def show_accuracy_pattern(history):
  # accuracy & loss graph
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(10,10))
  plt.subplot(1,2,1)
  plt.plot(epochs_range, acc, label = 'Training Accuracy')
  plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
  plt.legend(loc = 'lower right')
  plt.title('Training & Validation Accuracy')

  plt.subplot(1,2,2)
  plt.plot(epochs_range, loss, label = 'Training Loss')
  plt.plot(epochs_range, val_loss, label = 'Validation Loss')
  plt.legend(loc = 'upper right')
  plt.title('Training & Validation Loss')

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## for test set , creating only 1 batch
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    seed=123,
    batch_size=118,
    image_size=(img_height,img_width)
)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
print(len(class_names))
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
# 9

# %%
val_ds.class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# <h2 id="Visualize-the-data">Visualize the data</h2>
# <p><strong><span id="Todo,-create-a-code-to-visualize-one-instance-of-all-the-nine-classes-present-in-the-dataset">Todo, create a code to visualize one instance of all the nine classes present in the dataset</span></strong></p>
# <p>&nbsp;</p>

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

plot_idx=0
visited={}
visited_all=False
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(50):
  if not visited_all:
    for i in range(9):
      # print(images," | ",labels)
      # print(images.shape)
      # print(images[0].shape)
      # plt.figure(figsize=(20,20))
      if len(visited.keys())==9:
        visited_all=True
        break
      if class_names[labels[i]] in visited.keys():
        continue
      else:
        plt.subplot(3,3,plot_idx+1)
        plt.imshow(images[i].numpy().astype("uint8"));
        plt.title(class_names[labels[i]])
        visited[class_names[labels[i]]]="Y"
        plot_idx+=1
  else:
    break

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
# Do all the possible playing with Hyperparameters to get the best model. See if you can get a model which
# is not overfitting or underfitting
# Write down proper insights about your model

num_classes = 9

model_1_base = Sequential([
                layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height,img_width,3)),
                layers.Conv2D(16,3,padding='same',activation="relu"),
                layers.MaxPool2D((2,2),strides=2),


                layers.Conv2D(32,3,padding='same',activation="relu"),
                layers.MaxPool2D((2,2),strides=2),

                layers.Conv2D(64,3,padding='same',activation="relu"),
                layers.MaxPool2D((2,2),strides=2),

                layers.Flatten(),
                layers.Dense(64,activation="relu"),
                layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
# model_1_base.compile(optimizer='your_optimser',loss=your_loss_function_goes_here,metrics=['accuracy'])

model_1_base.compile(optimizer="adam",loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics = ['accuracy'])

# %%
# View the summary of all layers
model_1_base.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 64)                1982528
#
#  dense_1 (Dense)             (None, 9)                 585
#
# =================================================================
# Total params: 2006697 (7.65 MB)
# Trainable params: 2006697 (7.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model_1_base.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 28s 115ms/step - loss: 2.1068 - accuracy: 0.2048 - val_loss: 2.0431 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.9081 - accuracy: 0.3075 - val_loss: 1.7629 - val_accuracy: 0.3691
# Epoch 3/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.6965 - accuracy: 0.4085 - val_loss: 1.5996 - val_accuracy: 0.4452
# Epoch 4/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.4917 - accuracy: 0.4777 - val_loss: 1.4558 - val_accuracy: 0.5280
# Epoch 5/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3931 - accuracy: 0.5095 - val_loss: 1.3893 - val_accuracy: 0.5257
# Epoch 6/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.2863 - accuracy: 0.5474 - val_loss: 1.4172 - val_accuracy: 0.5190
# Epoch 7/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.2059 - accuracy: 0.5692 - val_loss: 1.4164 - val_accuracy: 0.5101
# Epoch 8/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.1680 - accuracy: 0.5915 - val_loss: 1.5105 - val_accuracy: 0.4989
# Epoch 9/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.0807 - accuracy: 0.6172 - val_loss: 1.4077 - val_accuracy: 0.5257
# Epoch 10/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.0365 - accuracy: 0.6289 - val_loss: 1.4846 - val_accuracy: 0.5593
# Epoch 11/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.9740 - accuracy: 0.6451 - val_loss: 1.5154 - val_accuracy: 0.5436
# Epoch 12/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.9405 - accuracy: 0.6590 - val_loss: 1.4329 - val_accuracy: 0.5414
# Epoch 13/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.9104 - accuracy: 0.6763 - val_loss: 1.5579 - val_accuracy: 0.5481
# Epoch 14/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.8220 - accuracy: 0.7020 - val_loss: 1.5811 - val_accuracy: 0.5324
# Epoch 15/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.7871 - accuracy: 0.7232 - val_loss: 1.5773 - val_accuracy: 0.5034
# Epoch 16/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.6907 - accuracy: 0.7422 - val_loss: 1.8524 - val_accuracy: 0.5459
# Epoch 17/20
# 56/56 [==============================] - 2s 27ms/step - loss: 0.6986 - accuracy: 0.7433 - val_loss: 1.8342 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 2s 27ms/step - loss: 0.6021 - accuracy: 0.7768 - val_loss: 2.1016 - val_accuracy: 0.5324
# Epoch 19/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.5865 - accuracy: 0.7746 - val_loss: 2.1164 - val_accuracy: 0.4564
# Epoch 20/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5673 - accuracy: 0.7885 - val_loss: 2.0444 - val_accuracy: 0.5414

# %% [markdown]
# ### Visualizing training results

# %%
show_accuracy_pattern(history)

# %% [markdown]
# # Observation - Overfitting
#
# 1.   Training Accuracy : Training Accuracy is high
# 2.   Validation Accuracy : Validation accuracy is low compared to the Training Accuracy so , its not a good model.
# 3.   Training Loss : Its decerasing
# 4.   Validation Loss : its increasing per epoch so not a good fit

# %% [markdown]
# # M2 Model ( With Augumentation)

# %%
augumentation_var = keras.Sequential([
                                      layers.experimental.preprocessing.RandomFlip(
                                                                                      mode="horizontal_and_vertical",
                                                                                      input_shape=(img_height,img_width,3)
                                                                                      ),
                                      layers.experimental.preprocessing.RandomRotation(
                                                                                        0.2,
                                                                                        fill_mode='reflect'
                                                                                        ),
                                      layers.experimental.preprocessing.RandomZoom(
                                                                                        height_factor=(0.2, 0.3),
                                                                                        width_factor=(0.2, 0.3),
                                                                                        fill_mode='reflect'
                                                                                  )
                                      ]
                                  )

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here


plot_idx=0
visited={}
visited_all=False
plt.figure(figsize=(10,30))
for images, labels in train_ds.take(50):
  if not visited_all:
    for i in range(9):
    # print(images," | ",labels)
      # print(images.shape)
      # print(images[0].shape)
      # plt.figure(figsize=(20,20))
      if len(visited.keys())==9:
        visited_all=True
        break
      if class_names[labels[i]] in visited.keys():
        continue
      else:
        plt.subplots_adjust(hspace=0.5)
        plt.subplot(9,2,plot_idx+1)
        x=augumentation_var(images)
        plt.imshow(x[i].numpy().astype("uint8"));
        # plt.imshow(images[i].numpy().astype("uint8"));
        plt.title("Augmented :- "+class_names[labels[i]])
        plot_idx+=1
        plt.subplot(9,2,plot_idx+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title("Original :- "+class_names[labels[i]])
        visited[class_names[labels[i]]]="Y"
        plot_idx+=1

  else:
    break


# Do all the possible playing with Hyperparameters to get the best model. See if you can get a model which
# is not overfitting or underfitting
# Write down proper insights about your model

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
## Your code goes here

model2_augumentation = Sequential([

        layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height,img_width,3)),  # Normalize pixel values
        augumentation_var,

        layers.Conv2D(16,3,padding='same',activation="relu"),
        layers.MaxPool2D((2,2),strides=2),

        layers.Conv2D(32,3,padding='same',activation="relu"),
        layers.MaxPool2D((2,2),strides=2),

        layers.Conv2D(64,3,padding='same',activation="relu"),
        layers.MaxPool2D((2,2),strides=2),
        layers.Dense(128,activation="relu"),

        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dense(256,activation="relu"),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.2),

        layers.Dense(9, activation='softmax')  # 9 classes in the output layer
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model2_augumentation.compile(optimizer="adam",loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics = ['accuracy'])
# model2_augumentation.compile(optimizer="adam",loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics = ['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
#train the model : run the model on train & validation set
epochs = 20
history = model2_augumentation.fit( train_ds , validation_data= val_ds , epochs = epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 39ms/step - loss: 1.9400 - accuracy: 0.2796 - val_loss: 1.6856 - val_accuracy: 0.4049
# Epoch 2/20
# 56/56 [==============================] - 2s 39ms/step - loss: 1.6830 - accuracy: 0.3884 - val_loss: 1.5976 - val_accuracy: 0.4631
# Epoch 3/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.6022 - accuracy: 0.4319 - val_loss: 1.5485 - val_accuracy: 0.4452
# Epoch 4/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.5026 - accuracy: 0.4632 - val_loss: 1.5013 - val_accuracy: 0.4765
# Epoch 5/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.4479 - accuracy: 0.4944 - val_loss: 1.4989 - val_accuracy: 0.4922
# Epoch 6/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.4264 - accuracy: 0.5017 - val_loss: 1.4578 - val_accuracy: 0.4989
# Epoch 7/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.4093 - accuracy: 0.5033 - val_loss: 1.6284 - val_accuracy: 0.4832
# Epoch 8/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.3849 - accuracy: 0.5123 - val_loss: 1.4275 - val_accuracy: 0.5168
# Epoch 9/20
# 56/56 [==============================] - 2s 38ms/step - loss: 1.3592 - accuracy: 0.5234 - val_loss: 1.5456 - val_accuracy: 0.5101
# Epoch 10/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.3481 - accuracy: 0.5301 - val_loss: 1.6576 - val_accuracy: 0.4743
# Epoch 11/20
# 56/56 [==============================] - 2s 37ms/step - loss: 1.3195 - accuracy: 0.5279 - val_loss: 1.3785 - val_accuracy: 0.5257
# Epoch 12/20
# 56/56 [==============================] - 2s 35ms/step - loss: 1.3040 - accuracy: 0.5435 - val_loss: 1.3603 - val_accuracy: 0.5302
# Epoch 13/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.3606 - accuracy: 0.5195 - val_loss: 1.4151 - val_accuracy: 0.5123
# Epoch 14/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.3255 - accuracy: 0.5223 - val_loss: 1.5005 - val_accuracy: 0.4877
# Epoch 15/20
# 56/56 [==============================] - 2s 35ms/step - loss: 1.2845 - accuracy: 0.5329 - val_loss: 1.3583 - val_accuracy: 0.5302
# Epoch 16/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.2920 - accuracy: 0.5346 - val_loss: 1.3862 - val_accuracy: 0.5145
# Epoch 17/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.2778 - accuracy: 0.5413 - val_loss: 1.3720 - val_accuracy: 0.5324
# Epoch 18/20
# 56/56 [==============================] - 2s 40ms/step - loss: 1.2785 - accuracy: 0.5480 - val_loss: 1.4657 - val_accuracy: 0.4877
# Epoch 19/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.3125 - accuracy: 0.5206 - val_loss: 1.6591 - val_accuracy: 0.4362
# Epoch 20/20
# 56/56 [==============================] - 2s 35ms/step - loss: 1.2922 - accuracy: 0.5223 - val_loss: 1.4152 - val_accuracy: 0.5123

# %% [markdown]
# ### Visualizing the results

# %%
show_accuracy_pattern(history)

# %% [markdown]
# #### **Todo: The model is still overfitting. But there is slight reduction in accuracy gap**

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# Answer : **seborrheic keratosis - 	77**
# #### - Which classes dominate the data in terms proportionate number of samples?
# Answer : **pigmented benign keratosis - 462 AND melanoma	- 438 dominate the numbers**

# %%
df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  Count of Image
# 0        basal cell carcinoma             376
# 1           actinic keratosis             114
# 2                       nevus             357
# 3     squamous cell carcinoma             181
# 4                    melanoma             438
# 5             vascular lesion             139
# 6  pigmented benign keratosis             462
# 7        seborrheic keratosis              77
# 8              dermatofibroma              95

# %% [markdown]
# ## **Todo:** Handling class imbalances:
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79C1D17AE350>: 100%|██████████| 500/500 [00:17<00:00, 28.69 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79C1D14BB3D0>: 100%|██████████| 500/500 [00:20<00:00, 24.62 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x79C1D1569570>: 100%|██████████| 500/500 [00:21<00:00, 23.26 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x79C25DB3D330>: 100%|██████████| 500/500 [01:31<00:00,  5.45 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x79C1D17C1D50>: 100%|██████████| 500/500 [01:25<00:00,  5.82 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x79C1D130F3D0>: 100%|██████████| 500/500 [00:16<00:00, 30.04 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x79C1D152ECB0>: 100%|██████████| 500/500 [00:40<00:00, 12.49 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79C25DB78190>: 100%|██████████| 500/500 [00:19<00:00, 25.46 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x79C25DB78100>: 100%|██████████| 500/500 [00:15<00:00, 31.40 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
#Count total number of image generated by Augmentor.
# image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
# print(image_count_train)

image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
# df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
# new_df = original_df.append(df2)

# %%
# new_df['Label'].value_counts()

# %%
# AUTOTUNE = tf.data.experimental.AUTOTUNE
# train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
# val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
# train dataset


train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
# validation dataset
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer

model4_augumentation = Sequential()
model4_augumentation.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer
#First Convulation layer
model4_augumentation.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model4_augumentation.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model4_augumentation.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model4_augumentation.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model4_augumentation.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model4_augumentation.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model4_augumentation.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model4_augumentation.add(layers.Flatten())

#Dense Layer
model4_augumentation.add(layers.Dense(128,activation='relu'))
# model4_augumentation.add(layers.Dense(256,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model4_augumentation.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model4_augumentation.add(layers.Dense(len(class_names),activation='softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model4_augumentation.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %% [markdown]
# #### **Todo:**  Train your model

# %%
# Train the model
epochs = 30
# history = model4_augumentation.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
history = model4_augumentation.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.9324 - accuracy: 0.2621
# Epoch 1: val_accuracy improved from -inf to 0.42094, saving model to model.h5
# 169/169 [==============================] - 38s 183ms/step - loss: 1.9312 - accuracy: 0.2624 - val_loss: 1.5606 - val_accuracy: 0.4209
# Epoch 2/30
# 169/169 [==============================] - ETA: 0s - loss: 1.6046 - accuracy: 0.3934
# Epoch 2: val_accuracy improved from 0.42094 to 0.43356, saving model to model.h5
# 169/169 [==============================] - 30s 173ms/step - loss: 1.6046 - accuracy: 0.3934 - val_loss: 1.4046 - val_accuracy: 0.4336
# Epoch 3/30
# 169/169 [==============================] - ETA: 0s - loss: 1.4234 - accuracy: 0.4555
# Epoch 3: val_accuracy improved from 0.43356 to 0.48998, saving model to model.h5
# 169/169 [==============================] - 31s 178ms/step - loss: 1.4234 - accuracy: 0.4555 - val_loss: 1.3683 - val_accuracy: 0.4900
# Epoch 4/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.3125 - accuracy: 0.4963
# Epoch 4: val_accuracy improved from 0.48998 to 0.52190, saving model to model.h5
# 169/169 [==============================] - 30s 175ms/step - loss: 1.3128 - accuracy: 0.4957 - val_loss: 1.2793 - val_accuracy: 0.5219
# Epoch 5/30
# 169/169 [==============================] - ETA: 0s - loss: 1.2023 - accuracy: 0.5451
# Epoch 5: val_accuracy improved from 0.52190 to 0.57758, saving model to model.h5
# 169/169 [==============================] - 30s 175ms/step - loss: 1.2023 - accuracy: 0.5451 - val_loss: 1.0955 - val_accuracy: 0.5776
# Epoch 6/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.0991 - accuracy: 0.5923
# Epoch 6: val_accuracy improved from 0.57758 to 0.63846, saving model to model.h5
# 169/169 [==============================] - 29s 165ms/step - loss: 1.0998 - accuracy: 0.5922 - val_loss: 0.9625 - val_accuracy: 0.6385
# Epoch 7/30
# 169/169 [==============================] - ETA: 0s - loss: 1.0092 - accuracy: 0.6222
# Epoch 7: val_accuracy did not improve from 0.63846
# 169/169 [==============================] - 34s 196ms/step - loss: 1.0092 - accuracy: 0.6222 - val_loss: 0.9793 - val_accuracy: 0.6192
# Epoch 8/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.9336 - accuracy: 0.6486
# Epoch 8: val_accuracy improved from 0.63846 to 0.67632, saving model to model.h5
# 169/169 [==============================] - 30s 176ms/step - loss: 0.9337 - accuracy: 0.6480 - val_loss: 0.8407 - val_accuracy: 0.6763
# Epoch 9/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.8527 - accuracy: 0.6745
# Epoch 9: val_accuracy improved from 0.67632 to 0.68523, saving model to model.h5
# 169/169 [==============================] - 28s 161ms/step - loss: 0.8530 - accuracy: 0.6745 - val_loss: 0.8545 - val_accuracy: 0.6852
# Epoch 10/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.7856 - accuracy: 0.7052
# Epoch 10: val_accuracy did not improve from 0.68523
# 169/169 [==============================] - 31s 178ms/step - loss: 0.7847 - accuracy: 0.7057 - val_loss: 0.9640 - val_accuracy: 0.6578
# Epoch 11/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.7260 - accuracy: 0.7360
# Epoch 11: val_accuracy improved from 0.68523 to 0.73348, saving model to model.h5
# 169/169 [==============================] - 31s 178ms/step - loss: 0.7267 - accuracy: 0.7361 - val_loss: 0.7524 - val_accuracy: 0.7335
# Epoch 12/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.6895 - accuracy: 0.7448
# Epoch 12: val_accuracy improved from 0.73348 to 0.74684, saving model to model.h5
# 169/169 [==============================] - 29s 166ms/step - loss: 0.6900 - accuracy: 0.7446 - val_loss: 0.6739 - val_accuracy: 0.7468
# Epoch 13/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.6568 - accuracy: 0.7541
# Epoch 13: val_accuracy improved from 0.74684 to 0.75650, saving model to model.h5
# 169/169 [==============================] - 32s 179ms/step - loss: 0.6568 - accuracy: 0.7543 - val_loss: 0.6567 - val_accuracy: 0.7565
# Epoch 14/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.5805 - accuracy: 0.7807
# Epoch 14: val_accuracy improved from 0.75650 to 0.79510, saving model to model.h5
# 169/169 [==============================] - 31s 181ms/step - loss: 0.5804 - accuracy: 0.7808 - val_loss: 0.5965 - val_accuracy: 0.7951
# Epoch 15/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.7935
# Epoch 15: val_accuracy did not improve from 0.79510
# 169/169 [==============================] - 31s 173ms/step - loss: 0.5395 - accuracy: 0.7936 - val_loss: 0.5863 - val_accuracy: 0.7944
# Epoch 16/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.5405 - accuracy: 0.7985
# Epoch 16: val_accuracy improved from 0.79510 to 0.79733, saving model to model.h5
# 169/169 [==============================] - 31s 179ms/step - loss: 0.5414 - accuracy: 0.7982 - val_loss: 0.6243 - val_accuracy: 0.7973
# Epoch 17/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4800 - accuracy: 0.8214
# Epoch 17: val_accuracy did not improve from 0.79733
# 169/169 [==============================] - 31s 178ms/step - loss: 0.4796 - accuracy: 0.8214 - val_loss: 0.6386 - val_accuracy: 0.7832
# Epoch 18/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4420 - accuracy: 0.8354
# Epoch 18: val_accuracy improved from 0.79733 to 0.80327, saving model to model.h5
# 169/169 [==============================] - 31s 179ms/step - loss: 0.4436 - accuracy: 0.8353 - val_loss: 0.5760 - val_accuracy: 0.8033
# Epoch 19/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4346 - accuracy: 0.8337
# Epoch 19: val_accuracy improved from 0.80327 to 0.81366, saving model to model.h5
# 169/169 [==============================] - 32s 181ms/step - loss: 0.4353 - accuracy: 0.8333 - val_loss: 0.5792 - val_accuracy: 0.8137
# Epoch 20/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4007 - accuracy: 0.8517
# Epoch 20: val_accuracy did not improve from 0.81366
# 169/169 [==============================] - 34s 197ms/step - loss: 0.4007 - accuracy: 0.8518 - val_loss: 0.7391 - val_accuracy: 0.7617
# Epoch 21/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4719 - accuracy: 0.8255
# Epoch 21: val_accuracy did not improve from 0.81366
# 169/169 [==============================] - 31s 180ms/step - loss: 0.4733 - accuracy: 0.8249 - val_loss: 0.6011 - val_accuracy: 0.8010
# Epoch 22/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.4102 - accuracy: 0.8551
# Epoch 22: val_accuracy improved from 0.81366 to 0.81811, saving model to model.h5
# 169/169 [==============================] - 31s 179ms/step - loss: 0.4105 - accuracy: 0.8550 - val_loss: 0.5490 - val_accuracy: 0.8181
# Epoch 23/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3648 - accuracy: 0.8629
# Epoch 23: val_accuracy did not improve from 0.81811
# 169/169 [==============================] - 31s 177ms/step - loss: 0.3657 - accuracy: 0.8626 - val_loss: 0.6053 - val_accuracy: 0.7862
# Epoch 24/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3477 - accuracy: 0.8679
# Epoch 24: val_accuracy improved from 0.81811 to 0.82257, saving model to model.h5
# 169/169 [==============================] - 34s 198ms/step - loss: 0.3477 - accuracy: 0.8678 - val_loss: 0.5593 - val_accuracy: 0.8226
# Epoch 25/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3714 - accuracy: 0.8588
# Epoch 25: val_accuracy did not improve from 0.82257
# 169/169 [==============================] - 34s 197ms/step - loss: 0.3721 - accuracy: 0.8585 - val_loss: 0.5792 - val_accuracy: 0.8033
# Epoch 26/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3642 - accuracy: 0.8590
# Epoch 26: val_accuracy did not improve from 0.82257
# 169/169 [==============================] - 31s 175ms/step - loss: 0.3638 - accuracy: 0.8592 - val_loss: 0.5661 - val_accuracy: 0.8144
# Epoch 27/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3199 - accuracy: 0.8836
# Epoch 27: val_accuracy improved from 0.82257 to 0.83890, saving model to model.h5
# 169/169 [==============================] - 31s 179ms/step - loss: 0.3191 - accuracy: 0.8839 - val_loss: 0.5409 - val_accuracy: 0.8389
# Epoch 28/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3043 - accuracy: 0.8828
# Epoch 28: val_accuracy did not improve from 0.83890
# 169/169 [==============================] - 31s 178ms/step - loss: 0.3045 - accuracy: 0.8828 - val_loss: 0.6726 - val_accuracy: 0.8107
# Epoch 29/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3471 - accuracy: 0.8700
# Epoch 29: val_accuracy improved from 0.83890 to 0.84113, saving model to model.h5
# 169/169 [==============================] - 34s 197ms/step - loss: 0.3467 - accuracy: 0.8702 - val_loss: 0.5993 - val_accuracy: 0.8411
# Epoch 30/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.3052 - accuracy: 0.8828
# Epoch 30: val_accuracy did not improve from 0.84113
# 169/169 [==============================] - 34s 196ms/step - loss: 0.3050 - accuracy: 0.8830 - val_loss: 0.6011 - val_accuracy: 0.8293

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
show_accuracy_pattern(history)

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# <div style="color: #000000; background-color: #f7f7f7; font-family: monospace, Menlo, Monaco, 'Courier New', monospace; font-weight: normal; font-size: 14px; line-height: 19px; white-space: pre;">
# <h3><span style="color: #000000;"><b>Analysis</b> : The model appears <strong>well-balanced</strong>, showing neither significant overfitting nor underfitting. </span></h3>
# <div><span style="color: #000000;">With consistent improvement in validation accuracy and close alignment with training accuracy, the model generalizes effectively. </span></div>
# <div><span style="color: #000000;">Evaluate final metrics on a test set for a comprehensive assessment.</span></div>
# <div>&nbsp;</div>
# </div>

# %%
def test_model_prediction(model_name, expected="melanoma", melanoma_path = "Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000013.jpg"):

    img = tf.keras.utils.load_img(
    melanoma_path, target_size=(img_height, img_width)
    )
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    predictions = model_name.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    # print(score)

    display(
    "Expected {}. Predicted {}:- with a {:.2f}%"
    .format(expected, test_ds.class_names[np.argmax(score)], 100 * np.max(score))
    )

    print("\n\n")

# %%
test_model_prediction(
    model4_augumentation,
    melanoma_path = "Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000029.jpg"
    )
# Out:
# 1/1 [==============================] - 0s 85ms/step
# 'Expected melanoma. Predicted melanoma:- with a 24.85%'
